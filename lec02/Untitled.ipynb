# %%
help
# Out:
# Type help() for interactive help, or help(object) for help about object.

# %%
help()
# Out:
# Welcome to Python 3.13's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.13/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  q
# You are now leaving help and returning to the Python interpreter.
# If you want to ask for help on a particular object directly from the
# interpreter, you can type "help(object)".  Executing "help('string')"
# has the same effect as typing a particular string at the help> prompt.

# %%
a="hello"

# %%
b='hi there'

# %%
print(a)
print(b)
# Out:
# hello
# hi there

# %%
print(type(a))
isinstance(a,str)
# Out:
# <class 'str'>
# True

# %%
print(a,b)
# Out:
# hello hi there

# %%
print(a+b)
# Out:
# hellohi there

# %%
print(a*3)
# Out:
# hellohellohello

# %%
print((a+" ")*23)
# Out:
# hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello hello

# %%
x=2
print('x is',x)
print('the type of x is',type(x))
# Out:
# x is 2
# the type of x is <class 'int'>

# %%
isinstance(x,int)
# Out:
# True

# %%
isinstance(x,float)
# Out:
# False

# %%
z=3.
print('z is',z)
print('the type of z is',type(z))
# Out:
# z is 3.0
# the type of z is <class 'float'>

# %%
isinstance(z,float)
# Out:
# True

# %%
isinstance(z,int)
# Out:
# False

# %%
y=1.12
print('y is',y)
print('the type of y is',type(y))
# Out:
# y is 1.12
# the type of y is <class 'float'>

# %%
isinstance(y,float)
# Out:
# True

# %%
x+z
# Out:
# 5.0

# %%
x*z
# Out:
# 6.0

# %%
x/z
# Out:
# 0.6666666666666666

# %%
x-z
# Out:
# -1.0

# %%
x**z
# Out:
# 8.0

# %%
0.05*4000
# Out:
# 200.0

# %%
if(x==2):
    print('x equals 2')
print('the if statement is over')
# Out:
# x equals 2
# the if statement is over

# %%
if(x==2):
    print('x equals 2')
    print('and the if statement is still running')
print('the if statement is over')
# Out:
# x equals 2
# and the if statement is still running
# the if statement is over

# %%
if(x==3):
    print('x equals 3')
    print('and the if statement is still running')
else:
    print('x is not equal to 3')
    print('...and so on...')
print('the if statement is over')
# Out:
# x is not equal to 3
# ...and so on...
# the if statement is over

# %%
def doubleme(x):
    print('running doubleme...')
    return 2*x

# %%
y=doubleme(4)
print('now y is',y)
# Out:
# running doubleme...
# now y is 8

# %%
y=doubleme(6)
print('now y is',y)
# Out:
# running doubleme...
# now y is 12

# %%
y=doubleme(25)
print('now y is',y)
# Out:
# running doubleme...
# now y is 50

# %%
import homework2
help(homework2)
# Out:
# Help on module homework2:
#
# NAME
#     homework2
#
# DESCRIPTION
#     This homework defines one method, called "arithmetic".
#     that method, type `help homework2.arithmetic`.
#
# FUNCTIONS
#     arithmetic(x, y)
#         Modify this code so that it performs one of four possible functions,
#         as specified in the following table:
#
#                             isinstance(x,str)  isinstance(x,float)
#         isinstance(y,str)   return x+y         return str(x)+y
#         isinstance(y,float) return x*int(y)    return x*y
#
# FILE
#     c:\users\-\kcgi\intro_speech_understanding\lec02\homework2.py

# %%
z=homework2.arithmetic("foo","bar")
print('now z is',z)
# Out:
# now z is 2000

# %%
import importlib
importlib.reload(homework2)
# Out:
# <module 'homework2' from 'C:\\Users\\-\\kcgi\\intro_speech_understanding\\lec02\\homework2.py'>

# %%
print(homework2.arithmetic("foo","bar"))
# Out:
# foobar

# %%
print(homework2.arithmetic("foo",3.12))
# Out:
# foofoofoo

# %%
print(homework2.arithmetic(3.12,"foo"))
# Out:
# 3.12foo

# %%
print(homework2.arithmetic(3.0,2.0))
# Out:
# 6.0

# %%
importlib.reload(grade)
# Out:
# ....
# ----------------------------------------------------------------------
# Ran 4 tests in 0.026s
#
# OK
# 4 successes out of 4 tests run
# Score: 100%
# <module 'grade' from 'C:\\Users\\-\\kcgi\\intro_speech_understanding\\lec02\\grade.py'>
